# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# #Universidad Autonoma de Bucaramanga
# ##Cantidad de Movimiento Lineal
#
# Laboratorio y Mecànica
#
#
#
# *   Carlos Javier Abaunza Caicedo, U00159124nto de lista
# *   Juan Sebastian Sanchez Nova, U00146939
# *   Julio Isaac Guzmàn Montoya, U0017414
#
# Revisado Por
#
# Prof. Juan Carlos Quijano Rojas
#
# 22 de octubre de 2022

# %% [markdown]
# #**1.   Objetivo**
#
# Entender y conocer por medio de la pràctica como son los diferentes tipos de colisionesElemento de lista
#
# #**2.   Introducciòn**
#
# Cuando dos o m´as cuerpos se aproximan entre s´ı, entre ellos act´uan fuerzas internas que
# hacen que su momento lineal y su energ´ıa var´ıen, produci´endose un intercambio entre ellos
# de ambas magnitudes. En este caso se dice que entre los cuerpos se ha producido una colisi´on
# o choque. Es preciso recalcar que, para que se produzca una colisi´on, no es necesario que
# los cuerpos hayan estado f´ısicamente en contacto en un sentido microsc´opico basta que se
# aproximen lo suficiente como para que haya habido interacci´on entre ellos.
# En el presente informe se analizar´a las colisiones el´asticas y las colisiones inel´asticas para
# ello se necesitar´a la ayuda un mecanismo para recrear una colicion entre dos masas a la
# hora de colicionar. Al finalizar dichas observciones se llevar´a a cabo la toma de datos para el
# respectivo an´alisis de cada una de esta colisiones (el´asticas e inel´asticas), y tambi´en se llevar´an
# a cabo sus respectivas comparaciones para as´ı sacar nuestras conclusiones respectivamente
#
# #**3.   Materiales**
#
# 3.1. Carril de aire
#
# Carril donde se moveran las masas, por el cual esta distribuido aire.
#
# 3.2. Bomba de aire
#
# Bomba que distribuye aire por el carril, eliminando la fricciòn entre las masas y el carril.
#
# 3.3. Carros
#
# Carros de masas diferentes utilizados como objetos de colisiòn
#
# 3.4. Sensores laser
#
# Sensores utilizados para medir la velocidad con la que se mueven las masas.

# %% [markdown]
# #**4.   Metodologìa**
# 1. Se realizaron tres lanzamientos: dos con colisi´on elastica y una con colisi´on inelastica.
# 2. Los lanzamientos se realizaron aumentando o disminuyendo la masa de los carros en
# cada lanzamiento, y as´ı obtener resultados variados.
# 3. Con ayuda del sensor se determin´o la velocidad con la que se mueve de cada masa
# antes y despu´es de chocar entre si.
# 4. Al final se calcula el coeficiente de restituci´on para determinar el tipo de colisi´on.
#
#
# ![image.png](data:image/png;base64,...)
#
#
# Figura 5.1: Sistema con el que se realiz´o el experimento.

# %% [markdown]
# #**5.   Anàlisis de Resultados**
# Como identificar el tipo de colisiòn:
#
#
# *   Si el coeficiente de restituci´on es 1, es una colisi´on elastica.
# *   Si el coeficiente de restituci´on esta entre 0 y 1, es una colisi´on parcialmente elastica
# o inelastica.
# *   Si el coeficiente de restituci´on es igual a 0, es una colisi´on inelastica.
#
# ##**5.1   Resultados Experimentales**
# Como identificar el tipo de colisiòn:
#
#
# *   Velocidades antes: *v*
# *    Velocidades despuès: *u*
# *   Coeficiente de restituciòn
# *   Momentum−→P
#
# ![1.jpg](data:image/jpeg;base64,...)
#
# Figura 5.4: Resultados del momentum y coeficiente de restituci´on.

# %% [markdown]
# #**5.2.   Fòrmulas utilizadas durante el experimento**
#
#
#
# *   −→P = m ·−→v
#
# *   −→P antes = m1 · v1 + m2 · v2
# *   −→P despues = m1 · u1 + m2 · u2
#
#
# *   Coeficiente de restituci´on: e =
# u2−u1
# v1−v2
#
#
#
#
# #**6.   Conclusiones**
#
# En esta pràctica se concluyò que la energìa no se crea ni se destruye, solo se
# transforma, esto quiere decir que la energìa total del sistema permanece constante
# y la energìa es la misma antes y despu´es de la transformaciòn, para poder llegar
# a esto es necesario que se cumpla algunos paràmetros como lo es el conocimiento
# de cada colisiòn.
